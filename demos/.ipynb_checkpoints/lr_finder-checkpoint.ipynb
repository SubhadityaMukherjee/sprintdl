# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import os
os.environ['TORCH_HOME'] = "/media/hdd/Datasets/"
import sys
sys.path.append("../")

# %%
from sprintdl.main import *
# from sprintdl.nets import *

# %%
device = torch.device('cuda',0)
from torch.nn import init
import torch
import math

# %% [markdown]
# # Define required

# %%
fpath = Path("/media/hdd/Datasets/ArtClass/")

tfms = [make_rgb, ResizeFixed(128), to_byte_tensor, to_float_tensor]
bs = 256

# %% [markdown]
# # Actual process

# %%
il = ImageList.from_files(fpath, tfms=tfms)

# %%
il
# Out:
# ImageList (36702 items)
# [PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/69030963_140928767119437_3621699865915593113_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/72464485_484151519164558_7996390942427275987_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/67061598_659075951237852_8193482831220395614_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/52369429_387255328723206_9033916457772710578_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/67249582_2358754971005882_1419227919627445111_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/53117277_787218161655836_7400982805295717482_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/66306740_2081645612139014_2862011611265245646_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/51053509_419271458822091_6368645951995838212_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/121360836_989537331451724_8045575910942555240_n.jpg'), PosixPath('/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/71523368_580759025792941_4235767755819951677_n.jpg')...]
# Path: /media/hdd/Datasets/ArtClass

# %%
tm= Path("/media/hdd/Datasets/ArtClass/Unpopular/mimang.art/69030963_140928767119437_3621699865915593113_n.jpg")

# %%
str(tm).split("/")[-3]
# Out:
# 'Unpopular'

# %%
sd = SplitData.split_by_func(il, partial(random_splitter, p_valid = .2))
ll = label_by_func(sd, lambda x: str(x).split("/")[-3], proc_y=CategoryProcessor())

# %%
n_classes = len(set(ll.train.y.items))

# %%
data = ll.to_databunch(bs, c_in=3, c_out=2)

# %%
show_batch(data, 4)

# %%
lr = .001
pct_start = 0.5
phases = create_phases(pct_start)
sched_lr  = combine_scheds(phases, cos_1cycle_anneal(lr/10., lr, lr/1e5))
sched_mom = combine_scheds(phases, cos_1cycle_anneal(0.95, 0.85, 0.95))

cbfs = [
    partial(AvgStatsCallback,accuracy),
    partial(ParamScheduler, 'lr', sched_lr),
    partial(ParamScheduler, 'mom', sched_mom),
    partial(BatchTransformXCallback, norm_imagenette),
    ProgressCallback,
    Recorder,
#     MixUp,
#     LR_Find,
    partial(CudaCallback, device)]

loss_func=LabelSmoothingCrossEntropy()
# arch = partial(xresnet34, n_classes)
arch = get_vision_model("resnet34", n_classes=n_classes, pretrained=True)

# opt_func = partial(sgd_mom_opt, wd=0.01)
opt_func = adam_opt(mom=0.9, mom_sqr=0.99, eps=1e-6, wd=1e-2)
# opt_func = lamb

# %% [markdown]
# # Training

# %%
clear_memory()

# %%
learn = Learner(arch,  data, loss_func, lr=lr, cb_funcs=cbfs, opt_func=opt_func)

# %%
lr_finder(learn, 1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Best loss : 0.6521751284599304
# Suggested lr : 7.244359600749898
# Set lr to suggested_lr
# 7.244359600749898

# %%
learn.fit(1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>456.414585</td>
#       <td>0.507289</td>
#       <td>820871.407285</td>
#       <td>0.500619</td>
#       <td>01:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit(3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>39.107801</td>
#       <td>0.504027</td>
#       <td>3.102059</td>
#       <td>0.499381</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>168.076324</td>
#       <td>0.503415</td>
#       <td>107591.363299</td>
#       <td>0.499381</td>
#       <td>02:02</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d3e932fce124> in <module>
# ----> 1 learn.fit(3)
#
# /media/hdd/github/sprintdl/sprintdl/core.py in fit(self, epochs, cbs, reset_opt)
#     157             for epoch in range(epochs):
#     158                 if not self.do_begin_epoch(epoch):
# --> 159                     self.all_batches()
#     160
#     161                 with torch.no_grad():
#
# /media/hdd/github/sprintdl/sprintdl/core.py in all_batches(self)
#     136         try:
#     137             for i, (xb, yb) in enumerate(self.dl):
# --> 138                 self.one_batch(i, xb, yb)
#     139         except CancelEpochException:
#     140             self("after_cancel_epoch")
#
# /media/hdd/github/sprintdl/sprintdl/core.py in one_batch(self, i, xb, yb)
#     124             self.loss.backward()
#     125             self("after_backward")
# --> 126             self.opt.step()
#     127             self("after_step")
#     128             self.opt.zero_grad()
#
# /media/hdd/github/sprintdl/sprintdl/optimizers.py in step(self)
#      51             state = self.state[p]
#      52             for stat in self.stats:
# ---> 53                 state = stat.update(p, state, **hyper)
#      54             compose(p, self.steppers, **state, **hyper)
#      55             self.state[p] = state
#
# /media/hdd/github/sprintdl/sprintdl/optimizers.py in update(self, p, state, mom, **kwargs)
#      76
#      77     def update(self, p, state, mom, **kwargs):
# ---> 78         state["mom_damp"] = tensor(1 - mom if self.dampening else 1.0)
#      79         state["grad_avg"].mul_(mom).add_(state["mom_damp"], p.grad.data)
#      80         return state
#
# KeyboardInterrupt:

# %%
save_model(learn, "m1", fpath)
# Out:
# Saved at /media/hdd/Datasets/ArtClass/models/m1
# PosixPath('/media/hdd/Datasets/ArtClass/models/m1')

# %%
temp = Path('/media/hdd/Datasets/ArtClass/Popular/artgerm/10004370_1657536534486515_1883801324_n.jpg')

get_class_pred(temp, learn ,ll, 128)
# Out:
# 'Popular'

# %%
temp = Path('/home/eragon/Downloads/Telegram Desktop/IMG_1800.PNG')

# %%
get_class_pred(temp, learn ,ll,128)
# Out:
# 'Unpopular'

# %%
temp = Path('/home/eragon/Downloads/Telegram Desktop/IMG_20210106_180731.jpg')

# %%
get_class_pred(temp, learn ,ll,128)
# Out:
# 'Popular'

# %% [markdown]
# # Digging in

# %%
# classification_report(learn, n_classes, device)

# %%
learn.recorder.plot_lr()

# %%
learn.recorder.plot_loss()

# %% [markdown]
# # Model vis

# %%
run_with_act_vis(1, learn)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.535883</td>
#       <td>0.762688</td>
#       <td>0.558465</td>
#       <td>0.741499</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Multiple runs with model saving

# %%
dict_runner = {
    "xres18":[1, partial(xresnet18, c_out=n_classes)(), data, loss_func, .001, cbfs,opt_func],
    "xres34":[1, partial(xresnet34, c_out=n_classes)(), data, loss_func, .001, cbfs,opt_func],
    "xres50":[1, partial(xresnet50, c_out=n_classes)(), data, loss_func, .001, cbfs,opt_func],
}

# %%
learn = Learner(arch(), data, loss_func, lr=lr, cb_funcs=cbfs, opt_func=opt_func)

# %%
multiple_runner(dict_runner, fpath)
# Out:
# Training model: xres18
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.631594</td>
#       <td>0.666667</td>
#       <td>0.598225</td>
#       <td>0.695818</td>
#       <td>01:47</td>
#     </tr>
#   </tbody>
# </table>
# Training model: xres34
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.635402</td>
#       <td>0.662340</td>
#       <td>0.597110</td>
#       <td>0.700699</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>
# Training model: xres50
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-129-2a6d724edb3b> in <module>
# ----> 1 multiple_runner(dict_runner, fpath)
#
# <ipython-input-128-92082ee24200> in multiple_runner(dict_run, save, save_path)
#       7 #         print(len(val))
#       8         learn = Learner(val[1], val[2], val[3], lr=val[4], cb_funcs=val[5], opt_func=val[6])
# ----> 9         learn.fit(val[0])
#      10         if save == True:
#      11             save_model(learn, i, save_path)
#
# /media/hdd/github/sprintdl/sprintdl/core.py in fit(self, epochs, cbs, reset_opt)
#     142             for epoch in range(epochs):
#     143                 if not self.do_begin_epoch(epoch):
# --> 144                     self.all_batches()
#     145
#     146                 with torch.no_grad():
#
# /media/hdd/github/sprintdl/sprintdl/core.py in all_batches(self)
#     121         try:
#     122             for i, (xb, yb) in enumerate(self.dl):
# --> 123                 self.one_batch(i, xb, yb)
#     124         except CancelEpochException:
#     125             self("after_cancel_epoch")
#
# /media/hdd/github/sprintdl/sprintdl/core.py in one_batch(self, i, xb, yb)
#     101             self.xb, self.yb = xb, yb
#     102             self("begin_batch")
# --> 103             self.pred = self.model(self.xb)
#     104             self("after_pred")
#     105             self.loss = self.loss_func(self.pred, self.yb)
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /media/hdd/github/sprintdl/sprintdl/nets.py in forward(self, x)
#      44
#      45     def forward(self, x):
# ---> 46         return act_fn(self.convs(x) + self.idconv(self.pool(x)))
#      47
#      48
#
# RuntimeError: CUDA out of memory. Tried to allocate 128.00 MiB (GPU 0; 7.80 GiB total capacity; 6.52 GiB already allocated; 72.31 MiB free; 6.68 GiB reserved in total by PyTorch)
